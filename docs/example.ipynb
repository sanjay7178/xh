# %% [markdown]
# # Xhell
#
# Xhell is Python library that aims to do ...
#
# ## Getting Started
#
# First, check our documentation about the [installation](/installation).
#
# Now, let's import our library:

# %%
from xh import xh

# %%
# linux specific
from xh import ls
print(ls('-l'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22092\533597138.py in <cell line: 0>()
#       1 from xh import ls
# ----> 2 print(ls('-l'))
#
# TypeError: 'str' object is not callable

# %%
from xh import ipconfig
ipconfig
# Out:
# <Command ipconfig>

# %%
# windows specific
# from xh import xh, CommandResult
import xh

result = xh.cmd("/c", "echo", "Hello, World!")

print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
print("Exit Code:", result.exitcode)
# Out:
# STDOUT: "Hello, World!"
#
# STDERR:
# Exit Code: 0

# %%
import xh
xh.cmd("/c", "dir", r"C:\Users\saisanjay\xh\docs")
# Out:
# ' Volume in drive C has no label.\n Volume Serial Number is 34AA-8ED5\n\n Directory of C:\\Users\\saisanjay\\xh\\docs\n\n02-04-2025  15:19    <DIR>          .\n02-04-2025  17:49    <DIR>          ..\n02-04-2025  15:19               599 changelog.md\n02-04-2025  15:29             8,017 contributing.md\n02-04-2025  18:05             5,688 example.ipynb\n02-04-2025  15:19    <DIR>          images\n02-04-2025  15:19             2,054 index.md\n02-04-2025  15:19               928 installation.md\n               5 File(s)         17,286 bytes\n               3 Dir(s)  95,322,804,224 bytes free\n'
